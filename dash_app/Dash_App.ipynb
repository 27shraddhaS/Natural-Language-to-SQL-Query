# %% [markdown]
# ## NGROK conection

# %%
from google.colab import files
image = files.upload()
# Out:
#      <input type="file" id="files-4c7197d8-333f-4820-8428-2d7f23851e47" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4c7197d8-333f-4820-8428-2d7f23851e47">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
# Out:
# --2021-05-23 14:20:23--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 52.204.190.140, 35.171.215.128, 34.193.233.154, ...
# Connecting to bin.equinox.io (bin.equinox.io)|52.204.190.140|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13832437 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.19M  54.6MB/s    in 0.2s
#
# 2021-05-23 14:20:23 (54.6 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13832437/13832437]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
get_ipython().system_raw('./ngrok http 8050 &')

# %%
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# http://0518c9ef970b.ngrok.io

# %% [markdown]
# ## Dash app

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Output,Input,State
import dash_table
external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = dash.Dash(__name__, external_stylesheets=external_stylesheets,suppress_callback_exceptions=True)

app.layout = html.Div([
    dcc.Location(id='url', refresh=False),
    html.Div(id='page-content')
])


index_page = html.Div([
    html.Div(
    dcc.Input(id="user", type="text", placeholder="Enter Username",className="inputbox1",
             style={'margin-left':'35%','width':'450px','height':'45px','padding':'10px','margin-top':'60px',
                     'font-size':'16px','border-width':'3px','border-color':'#a0a3a2'

                    }),
    ),
    html.Div(
    dcc.Input(id="passw", type="text", placeholder="Enter Password",className="inputbox2",
             style={'margin-left':'35%','width':'450px','height':'45px','padding':'10px','margin-top':'10px',
                     'font-size':'16px','border-width':'3px','border-color':'#a0a3a2',

                    }),
    ),
    html.Div(
    html.Button('Verify', id='verify', n_clicks=0, style={'font-size':'14px','background-color':'#5d966b','color':'#011706','border-width':'0px'}),
    style={'margin-left':'45%','padding-top':'30px'}),
    html.Div(id='output1'),
    html.Div(style={'height':'1500px'})

],style={'background-color':'#8bcc90'})


@app.callback(
    dash.dependencies.Output('output1', 'children'),
    [dash.dependencies.Input('verify', 'n_clicks')],
    state=[State('user', 'value'),
         State('passw', 'value')])

def update_output(n_clicks, uname, passw):
    print('>>>>>>>>>>>>',uname,passw,type(uname),type(passw))

    li={'shraddha':'admin123','shreetija':'admin123'}
    if uname =='' or uname == None or passw =='' or passw == None:
        return html.Div(children='',style={'padding-left':'550px','padding-top':'10px'})

    if uname not in li:
        return html.Div(children='Incorrect Username',style={'padding-left':'550px','padding-top':'40px','font-size':'16px'})

    if li[uname]==passw:
        return html.Div(dcc.Link('Access Granted! Go to NL-SQL', href='/NL-SQL',style={'color':'#121a14','font-family': 'serif', 'font-weight': 'bold', "text-decoration": "none",'font-size':'20px'}),style={'padding-left':'605px','padding-top':'40px'})
    else:
        return html.Div(children='Incorrect Password',style={'padding-left':'550px','padding-top':'40px','font-size':'16px'})

members_page = html.Div([
    html.Div(dcc.Link('Back', href='/NL-SQL',style={'color':'#bed4c4','font-family': 'serif', 'font-weight': 'bold', "text-decoration": "none",'font-size':'20px'}),style={'padding-left':'80%','padding-top':'10px','display':'inline-block'}),

    html.H1(children="The Team",className="ap",style={
    'color':'#89b394','text-align':'center','justify':'center','padding-top':'50px','font-weight':'bold','font-size':'40px',
    'font-family':'courier',
    'padding-left':'1px'

            }),
    html.Div(children="Shraddha Shekhar",style={'height':'400px','width':'19%','display':'inline-block','margin-left':'150px','background-color':'#7fb88d','margin-top':'100px','font-size':'22px','text-align':'center','color':'#121a14','padding-top':'20px'}),
    html.Div(children="Samiksha Shirgave",style={'height':'400px','width':'19%','display':'inline-block','margin-left':'20px','background-color':'#7fb88d','font-size':'22px','text-align':'center','color':'#121a14','padding-top':'20px'}),
    html.Div(children="Shreetija Salunke",style={'height':'400px','width':'19%','display':'inline-block','margin-left':'20px','background-color':'#7fb88d','font-size':'22px','text-align':'center','color':'#121a14','padding-top':'20px'}),
    html.Div(children="Harshada Jadhav",style={'height':'400px','width':'19%','display':'inline-block','margin-left':'20px','background-color':'#7fb88d','font-size':'22px','text-align':'center','color':'#121a14','padding-top':'20px'}),
    html.Div(style={'height':'500px'})
],style={'background-color':'#121a14'})

page_nl_sql = html.Div([
    html.Div([
    html.Div(dcc.Link('Log out', href='/',style={'color':'#bed4c4','font-family': 'serif', 'font-weight': 'bold', "text-decoration": "none",'font-size':'20px'}),style={'padding-left':'80%','padding-top':'10px','display':'inline-block'}),
    html.Div(dcc.Link('Members', href='/members',style={'color':'#bed4c4','font-family': 'serif', 'font-weight': 'bold', "text-decoration": "none",'font-size':'20px'}),style={'padding-left':'50px','padding-top':'10px','display':'inline-block'}),
    ]),
    html.Div(children=[
            html.H1(children="NL -> SQL",className="appht",style={
    'color':'#89b394','text-align':'center','justify':'center','padding-top':'170px','font-weight':'bold','font-size':'55px',
    'font-family':'courier',
    'padding-left':'1px'

            }),
        html.H5(children="Natural Language to SQL Query",className="appht1",style={
    'color':'#89b394','text-align':'center','justify':'center',
    'font-family':'courier',
    'padding-left':'1px'

            }),


    dcc.Input(id="input1", type="text", placeholder="Enter the question...",className="inputbox",
              style={'margin-left':'15%','width':'900px','height':'50px','padding':'20px','background-color':'#5d966b','margin-top':'60px','color':'#011706','border-radius':'10px',
                     'font-size':'20px','border-width':'0px 0px 5px 5px','border-color':'#3d6346',
                     'placeholder':{'color':'#011706'}
                    }),

    html.Button('Convert', id='submit-val', n_clicks=0, style={'margin-left':'70px','border-width':'3px','color':'#bed4c4','font-size':'14px'}),
    html.Div([
    html.Div(id='output2',className="outputc",style={'margin-left':'12%','background-color':'#7fb88d','height':'120px','width':'950px','justify':'center','margin-top':'30px','border-radius':'10px','padding':'20px','font-size':'20px','color':'#011706','display':'inline-block'}),

    html.Button('Execute', id='execute', n_clicks=0, style={'margin-left':'30px','margin-top':'70px','border-width':'3px','color':'#bed4c4','vertical-align':'top','font-size':'14px','display':'inline-block'}),
    ]),
    html.Div(id='output3',className="outputdb",style={'margin-left':'15%','height':'1000px','width':'900px','justify':'center','margin-top':'30px','border-radius':'10px','padding':'20px','font-size':'20px','color':'#011706'}),

    html.Div(style={'height':'500px'})

])

],style={'background-color':'#121a14'})


#CallBacks

@app.callback(
    dash.dependencies.Output('output2', 'children'),
    [dash.dependencies.Input('submit-val', 'n_clicks')],
    [dash.dependencies.State('input1', 'value')],
    )
def update_output(n_clicks, value):

    final_query = convert_nlp_sql(value)
    return final_query

@app.callback(
    dash.dependencies.Output('output3', 'children'),
    [dash.dependencies.Input('execute', 'n_clicks')],
    [dash.dependencies.State('input1', 'value')],
    )
def update_output2(n_clicks, value):

    final_query = convert_nlp_sql(value)
    if 'SELECT' in final_query:
      df_db = pd.read_sql_query(final_query, db)
      return html.Div([dash_table.DataTable(
    id='table',
    columns=[{"name": i, "id": i} for i in df_db.columns],
    data=df_db.to_dict('records'),
)])
    else:
      try:
        db.execute(final_query)
        if 'DELETE' in final_query:
          return html.Div(children='Records Deleted Successfully! ',style={'background-color':'#e1ede7','heigth':'40px','width':'950px','margin-left':'15%','border-radius':'10px'})
        elif 'CREATE' in final_query:
          return html.Div(children='Record Created Successfully! ',style={'background-color':'#e1ede7','heigth':'40px','width':'950px','margin-left':'15%','border-radius':'10px'})
      except:
        return html.Div(children='Invalid Query! ',style={'background-color':'#e1ede7','heigth':'40px','width':'950px','margin-left':'15%','border-radius':'10px'})



@app.callback(dash.dependencies.Output('page-content', 'children'),
              [dash.dependencies.Input('url', 'pathname')])
def display_page(pathname):
    if pathname == '/NL-SQL':
        return page_nl_sql
    elif pathname == '/members':
        return members_page
    else:
        return index_page


if __name__=='__main__':
  app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [23/May/2021 15:06:40] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [23/May/2021 15:06:40] "GET /_dash-component-suites/dash_renderer/react@16.v1_9_1m1621775661.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [23/May/2021 15:06:40] "GET /_dash-component-suites/dash_renderer/polyfill@7.v1_9_1m1621775661.8.7.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [23/May/2021 15:06:40] "GET /_dash-component-suites/dash_renderer/react-dom@16.v1_9_1m1621775661.14.0.min.js HTTP/1.1" 200 -
# ...
